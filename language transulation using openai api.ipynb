# %%
import openai
openai.api_key="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"

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
text="surendhar raaj c"
prompt=f'''
convert the given text into 5 other languages in which the language should not contain any english alphabets
given text:{text}
'''
response=get_completion(prompt)
print(response)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\Anaconda\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\Anaconda\lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File ~\Anaconda\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# ...

# %%
text1="சுரேந்தர் ராஜ் சி"
prompt1=f'''
find the given text is in which language
given text:{text1}
'''
response1=get_completion(prompt1)
print(response1)
# Out:
# The given text is in Tamil language.

# %%
prompt=input("enter what to be searched:")
response=get_completion(prompt)
print(response)
# Out:
# enter what to be searched:tree
# A tree is a perennial plant with a single stem or trunk, supporting branches and leaves. Trees are typically tall and have a woody structure, with a root system that anchors them to the ground and absorbs water and nutrients. Trees play a vital role in the ecosystem, providing oxygen, shade, shelter, and food for a variety of animals. They also help to regulate the climate by absorbing carbon dioxide from the atmosphere and releasing oxygen. Trees come in many different shapes and sizes, from towering redwoods to small fruit trees.
